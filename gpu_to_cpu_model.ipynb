# %%
# %%capture
from google.colab import drive, files
drive.mount('/content/gdrive', force_remount=True)

# %tensorflow_version 2.0.1
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········

# %%
import sys
import matplotlib.pyplot as plt
import tensorflow.keras.models
import numpy as np
import os.path

google_colab = "google.colab" in sys.modules
if google_colab:
    sys.path.append("./gdrive/My Drive/Colab Notebooks/DeepFRET-Model")
    plt.style.use("default")

from lib.model import create_deepconvlstm_model as create_model

OUTDIR = "./gdrive/My Drive/Colab Notebooks/DeepFRET-Model/output"
NAME = "sim_2c_best_model" # don't add .h5

# Create empty model and load in weights from GPU model
CPU_model = create_model(google_colab = False, n_features = 2, regression = False)
CPU_model.load_weights(os.path.join(OUTDIR, NAME + "_weights.h5"))

# Save
tensorflow.keras.models.save_model(CPU_model, os.path.join(OUTDIR, NAME + "_cpu.h5"))

print("Done!")
# Out:
# Done!
